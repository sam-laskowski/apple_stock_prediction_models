# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib

# %%
data = yf.download("AAPL", start="2010-01-01", end="2024-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.454506
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.465664
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.362820
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.351058
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.393281
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  192.868149
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.320221
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.419830
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  192.848206
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  191.802185
#
#                Volume        MA50       MA200  Momentum5  Momentum20  \
# Date
# 2010-01-04  493729600         NaN         NaN        NaN         NaN
# 2010-01-05  601904800         NaN         NaN        NaN         NaN
# 2010-01-06  552160000         NaN         NaN        NaN         NaN
# 2010-01-07  477131200         NaN         NaN        NaN         NaN
# 2010-01-08  447610800         NaN         NaN        NaN         NaN
# ...               ...         ...         ...        ...         ...
# 2023-12-22   37122800  185.398801  178.649100  -3.970001    3.630005
# 2023-12-26   28919300  185.682801  178.871851  -2.839996    3.260010
# 2023-12-27   48087700  185.971400  179.085250  -3.790009    2.750000
# 2023-12-28   34049900  186.300001  179.290201  -1.250000    4.210007
# 2023-12-29   42628800  186.633801  179.487900  -2.149994    2.580002
#
#                   Lag1        Lag5
# Date
# 2010-01-04         NaN         NaN
# 2010-01-05    7.643214         NaN
# 2010-01-06    7.656429         NaN
# 2010-01-07    7.534643         NaN
# 2010-01-08    7.520714         NaN
# ...                ...         ...
# 2023-12-22  194.679993  197.570007
# 2023-12-26  193.600006  195.889999
# 2023-12-27  193.050003  196.940002
# 2023-12-28  193.149994  194.830002
# 2023-12-29  193.580002  194.679993
#
# [3522 rows x 12 columns]

# %% [markdown]
# Pre-process data

# %%
# handle missing data using interpolation
data = data.interpolate(method='linear', axis=0).ffill().bfill() # draws straight line between known values and fills in the missing values

# %% [markdown]
# Feature Engineering

# %%
# create moving averages
data['MA50'] = data['Close'].rolling(window=50).mean()
data['MA200'] = data['Close'].rolling(window=200).mean()

# create momentum indicators
data['Momentum5'] = data['Close'].diff(periods=5)
data['Momentum20'] = data['Close'].diff(periods=20)

# create lagged returns
data['Lag1'] = data['Close'].shift(1)
data['Lag5'] = data['Close'].shift(5)

# %%
print(data.isnull().sum())

data = data.dropna()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# MA50           49
# MA200         199
# Momentum5       5
# Momentum20     20
# Lag1            1
# Lag5            5
# dtype: int64

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-10-18   11.373929   11.392857   11.224643   11.357143    9.590826
# 2010-10-19   10.835714   11.206071   10.715000   11.053214    9.334167
# 2010-10-20   11.035714   11.223214   10.959643   11.090357    9.365534
# 2010-10-21   11.155714   11.240714   10.957143   11.054286    9.335072
# 2010-10-22   11.038214   11.072857   10.939286   10.981071    9.273244
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  192.868149
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.320221
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.419830
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  192.848206
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  191.802185
#
#                 Volume        MA50       MA200  Momentum5  Momentum20  \
# Date
# 2010-10-18  1093010800    9.659357    8.767198   0.808573    1.241786
# 2010-10-19  1232784000    9.693457    8.784248   0.391071    0.918571
# 2010-10-20   721624400    9.729971    8.801418   0.371071    0.813571
# 2010-10-21   551460000    9.772350    8.819016   0.257500    0.735715
# 2010-10-22   372778000    9.812121    8.836318  -0.259643    0.541072
# ...                ...         ...         ...        ...         ...
# 2023-12-22    37122800  185.398801  178.649100  -3.970001    3.630005
# 2023-12-26    28919300  185.682801  178.871851  -2.839996    3.260010
# 2023-12-27    48087700  185.971400  179.085250  -3.790009    2.750000
# 2023-12-28    34049900  186.300001  179.290201  -1.250000    4.210007
# 2023-12-29    42628800  186.633801  179.487900  -2.149994    2.580002
#
#                   Lag1        Lag5
# Date
# 2010-10-18   11.240714   10.548571
# 2010-10-19   11.357143   10.662143
# 2010-10-20   11.053214   10.719286
# 2010-10-21   11.090357   10.796786
# 2010-10-22   11.054286   11.240714
# ...                ...         ...
# 2023-12-22  194.679993  197.570007
# 2023-12-26  193.600006  195.889999
# 2023-12-27  193.050003  196.940002
# 2023-12-28  193.149994  194.830002
# 2023-12-29  193.580002  194.679993
#
# [3323 rows x 12 columns]

# %% [markdown]
# Splitting data into Test and Train sets

# %%
X = data[['Open', 'High', 'Low', 'Volume', 'MA50', 'MA200', 'Momentum5', 'Momentum20', 'Lag1', 'Lag5']]
y = data['Close']

# %%
# split into train and test splits
train_size = int(len(data) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
y_train_categorical = (y_train > y_train.shift(1)).astype(int)  # 1 if price goes up, 0 otherwise

y_test_categorical = (y_test > y_test.shift(1)).astype(int)

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train_categorical)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test_categorical, y_pred)
precision = precision_score(y_test_categorical, y_pred)
recall = recall_score(y_test_categorical, y_pred)
f1 = f1_score(y_test_categorical, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# Accuracy: 0.5218045112781955
# Precision: 0.5218045112781955
# Recall: 1.0
# F1-score: 0.6857707509881423

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error (MSE): 2.85753342273026e-23
# Root Mean Squared Error (RMSE): 5.345590166417792e-12
# Mean Absolute Error (MAE): 5.286480693467823e-12
# R-squared: 1.0

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6310308872192.0000 - val_loss: 16260444160.0000
# Epoch 2/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36693377024.0000 - val_loss: 64290684.0000
# Epoch 3/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84572216.0000 - val_loss: 1781224.6250
# Epoch 4/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13483614.0000 - val_loss: 69072.7031
# Epoch 5/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 630707.7500 - val_loss: 214314.1875
# Epoch 6/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 338397.9375 - val_loss: 4191.8838
# Epoch 7/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63916.2227 - val_loss: 21026.0254
# Epoch 8/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11482.6260 - val_loss: 75702.3594
# Epoch 9/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 847703.3750 - val_loss: 96825.4297
# Epoch 10/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 137453.7344 - val_loss: 18320.7734
# Epoch 11/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6595.7251 - val_loss: 5279.2188
# Epoch 12/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 622690.3125 - val_loss: 735712.7500
# Epoch 13/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46845640.0000 - val_loss: 333566688.0000
# Epoch 14/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1660400128.0000 - val_loss: 2636886528.0000
# Epoch 15/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20051195904.0000 - val_loss: 58862844.0000
# Epoch 16/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1421163888640.0000 - val_loss: 153993658368.0000
# Epoch 17/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 362007527424.0000 - val_loss: 1619699840.0000
# Epoch 18/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3152212736.0000 - val_loss: 2992105.0000
# Epoch 19/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7613568.5000 - val_loss: 30520.6230
# Epoch 20/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 349416.2812 - val_loss: 8797.0283
# Epoch 21/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1540.7311 - val_loss: 12993.3926
# Epoch 22/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1088.7716 - val_loss: 13050.2012
# Epoch 23/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1400.5272 - val_loss: 10731.8574
# Epoch 24/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4175.2124 - val_loss: 15437.3154
# Epoch 25/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1694.9115 - val_loss: 9435.7061
# Epoch 26/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39051.5156 - val_loss: 15738.4434
# Epoch 27/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14194.3301 - val_loss: 4130.5039
# Epoch 28/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62709.3789 - val_loss: 13317.8027
# Epoch 29/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 270323.3125 - val_loss: 43563.1953
# Epoch 30/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32654.6465 - val_loss: 16047.8105
# Epoch 31/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 159627.4219 - val_loss: 4264.8027
# Epoch 32/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6356062.5000 - val_loss: 889014.7500
# Epoch 33/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 73918856.0000 - val_loss: 59446596.0000
# Epoch 34/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4726425600.0000 - val_loss: 478028448.0000
# Epoch 35/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2239895437312.0000 - val_loss: 512199163904.0000
# Epoch 36/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1057060356096.0000 - val_loss: 2825485568.0000
# Epoch 37/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45793538048.0000 - val_loss: 87782448.0000
# Epoch 38/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 166732656.0000 - val_loss: 46689.3203
# Epoch 39/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 76589.0938 - val_loss: 3245.4155
# Epoch 40/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6031.0942 - val_loss: 9550.3877
# Epoch 41/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 761.2188 - val_loss: 9036.3457
# Epoch 42/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1009.9313 - val_loss: 9215.0938
# Epoch 43/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 690.9586 - val_loss: 9934.1621
# Epoch 44/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 718.0603 - val_loss: 7901.6699
# Epoch 45/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 845.0013 - val_loss: 9429.0957
# Epoch 46/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 744.9201 - val_loss: 8299.9375
# Epoch 47/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 815.8315 - val_loss: 8928.8486
# Epoch 48/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 743.4611 - val_loss: 10410.0469
# Epoch 49/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 776.8692 - val_loss: 11189.5371
# Epoch 50/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7059.1626 - val_loss: 3336.9319
# Epoch 51/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85966.4375 - val_loss: 3595.3477
# Epoch 52/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 92519.5391 - val_loss: 42070.3789
# Epoch 53/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19774.5801 - val_loss: 7552.0547
# Epoch 54/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 311706.0938 - val_loss: 7716.5591
# Epoch 55/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22378.2910 - val_loss: 14092.0537
# Epoch 56/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1499715.0000 - val_loss: 9257808.0000
# Epoch 57/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22584024.0000 - val_loss: 164112.4688
# Epoch 58/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 175657504.0000 - val_loss: 116125216.0000
# Epoch 59/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21393674240.0000 - val_loss: 23130687488.0000
# Epoch 60/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 158096539648.0000 - val_loss: 169777348608.0000
# Epoch 61/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5732785717248.0000 - val_loss: 54354444288.0000
# Epoch 62/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143548514304.0000 - val_loss: 5881595392.0000
# Epoch 63/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51778379776.0000 - val_loss: 31531962.0000
# Epoch 64/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 244601632.0000 - val_loss: 3840826.5000
# Epoch 65/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8782058.0000 - val_loss: 23908.1914
# Epoch 66/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49941.0195 - val_loss: 5998.3174
# Epoch 67/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 589.5061 - val_loss: 7254.0220
# Epoch 68/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 517.7136 - val_loss: 6564.8394
# Epoch 69/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 540.2142 - val_loss: 6793.3130
# Epoch 70/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 617.1444 - val_loss: 6469.6055
# Epoch 71/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 546.8522 - val_loss: 5050.0405
# Epoch 72/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1870.9855 - val_loss: 4392.9092
# Epoch 73/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2464.7759 - val_loss: 6088.2319
# Epoch 74/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 480.8558 - val_loss: 6353.0693
# Epoch 75/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 644.0957 - val_loss: 3154.7512
# Epoch 76/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2882.4648 - val_loss: 6712.4067
# Epoch 77/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 547.3846 - val_loss: 6300.3438
# Epoch 78/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 616.2984 - val_loss: 6610.2500
# Epoch 79/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 532.4206 - val_loss: 6934.8496
# Epoch 80/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 546.2146 - val_loss: 7860.6240
# Epoch 81/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 723.6249 - val_loss: 6129.4346
# Epoch 82/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4176.4629 - val_loss: 6523.5063
# Epoch 83/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 562.4377 - val_loss: 3550.2449
# Epoch 84/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4766.2031 - val_loss: 10492.3350
# Epoch 85/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19674.5039 - val_loss: 10059.5293
# Epoch 86/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37697.8711 - val_loss: 164520.2500
# Epoch 87/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9364517.0000 - val_loss: 3474042.5000
# Epoch 88/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7858815.0000 - val_loss: 429575.4375
# Epoch 89/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 581844.8125 - val_loss: 1272819.3750
# Epoch 90/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12556586.0000 - val_loss: 1665913.5000
# Epoch 91/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 498051776.0000 - val_loss: 3212832000.0000
# Epoch 92/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 353922514944.0000 - val_loss: 156852060160.0000
# Epoch 93/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3539367362560.0000 - val_loss: 64067383296.0000
# Epoch 94/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 278966632448.0000 - val_loss: 2171499008.0000
# Epoch 95/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2154171648.0000 - val_loss: 1899480.0000
# Epoch 96/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5020785.5000 - val_loss: 3803.6562
# Epoch 97/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 450.4993 - val_loss: 5512.6313
# Epoch 98/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 376.9096 - val_loss: 4601.1689
# Epoch 99/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 360.7580 - val_loss: 4741.4814
# Epoch 100/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 351.9698 - val_loss: 4667.3516

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared: {r2}")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error (MSE): 14951.672378488829
# Root Mean Squared Error (RMSE): 122.27703127934056
# Mean Absolute Error (MAE): 121.198113956308
# R-squared: -43.793482488350655
